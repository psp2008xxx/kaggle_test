# %%
import pandas as pd

# %%
wine_reviews = pd.read_csv(r'E:\test_data\winemag-data-130k-v2.csv')

# %%
wine_reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
wine_reviews.shape
# Out:
# (129971, 14)

# %%
wine_reviews = pd.read_csv(r'E:\test_data\winemag-data-130k-v2.csv', index_col=0)

# %%
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
wic = pd.read_excel(r'E:\test_data\xls_files_all\WICAgencies2013ytd.xls',sheet_name='Total Women')

# %%
wic.head()
# Out:
#   WIC PROGRAM -- TOTAL NUMBER OF WOMEN PARTICIPATING           Unnamed: 1  \
# 0                                   FISCAL YEAR 2013                  NaN
# 1                        Data as of January 05, 2018                  NaN
# 2                                                NaN                  NaN
# 3         State Agency or Indian Tribal Organization  2012-10-01 00:00:00
# 4                                        Connecticut                11891
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3  2012-11-01 00:00:00  2012-12-01 00:00:00  2013-01-01 00:00:00
# 4                11763                11328                11786
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# ...

# %%
wic.shape
# Out:
# (106, 14)

# %%
import sqlite3

# %%
conn = sqlite3.connect(r'E:\test_data\FPA_FOD_20170508.sqlite')

# %%
fires = pd.read_sql_query('select * from fires', conn)

# %%
fires.head()
# Out:
#    OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 0         1       1  FS-1418826                FED   FS-FIRESTAT
# 1         2       2  FS-1418827                FED   FS-FIRESTAT
# 2         3       3  FS-1418835                FED   FS-FIRESTAT
# 3         4       4  FS-1418845                FED   FS-FIRESTAT
# 4         5       5  FS-1418847                FED   FS-FIRESTAT
#
#   NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  NWCG_REPORTING_UNIT_NAME  \
# 0                    FS                USCAPNF    Plumas National Forest
# 1                    FS                USCAENF  Eldorado National Forest
# 2                    FS                USCAENF  Eldorado National Forest
# 3                    FS                USCAENF  Eldorado National Forest
# 4                    FS                USCAENF  Eldorado National Forest
#
#   SOURCE_REPORTING_UNIT SOURCE_REPORTING_UNIT_NAME  \
# 0                  0511     Plumas National Forest
# ...

# %%
wine_reviews.head().to_csv(r'E:\test_data\kuni_wine_reviews.csv')

# %%
wic.to_excel(r'E:\test_data\kuni_wic.xlsx', sheet_name='Total Women')

# %%
conn =sqlite3.connect(r'E:\test_data\kuni_fires.sqlite')
fires.head(10).to_sql('fires', conn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-082c9d22953d> in <module>()
#       1 conn =sqlite3.connect(r'E:\test_data\kuni_fires.sqlite')
# ----> 2 fires.head(10).to_sql('fires', conn)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2125         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2126                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2127                    dtype=dtype)
#    2128
#    2129     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
# ...

# %%
fires2 = pd.read_sql_query('select * from fires', conn)

# %%
fires.head(10)

# %%
df = pd.DataFrame({'Apples':[35, 41], 'Bananas':[21, 34]}, index=['2017 Sales', '2018 Sales'])

# %%
df

# %%
se = pd.Series(['4 cups', '1 cup', '2 large', '1 can'], index=['Flour', 'Milk', 'Eggs', 'Spam'], name='Dinner')

# %%
reviews = pd.read_csv(r'E:\test_data\winemag-data-130k-v2.csv', index_col=0)

# %%
reviews.shape
# Out:
# (129971, 13)

# %%
reviews.iloc[:, 0]
# Out:
# 0               Italy
# 1            Portugal
# 2                  US
# 3                  US
# 4                  US
# 5               Spain
# 6               Italy
# 7              France
# 8             Germany
# 9              France
# 10                 US
# 11             France
# 12                 US
# 13              Italy
# 14                 US
# 15            Germany
# 16          Argentina
# 17          Argentina
# 18              Spain
# 19                 US
# 20                 US
# 21                 US
# 22              Italy
# 23                 US
# 24              Italy
# 25                 US
# 26              Italy
# 27              Italy
# 28              Italy
# 29                 US
#              ...
# 129941             US
# 129942             US
# 129943          Italy
# 129944         Israel
# 129945             US
# 129946        Germany
# 129947          Italy
# 129948      Argentina
# 129949             US
# 129950             US
# ...

# %%
reviews.head(3)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    points  price           province           region_1           region_2  \
# 0      87    NaN  Sicily & Sardinia               Etna                NaN
# 1      87   15.0              Douro                NaN                NaN
# 2      87   14.0             Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# ...

# %%
reviews.loc[:, ['taster_name', 'taster_twitter_handle', 'points']]
# Out:
#                taster_name taster_twitter_handle  points
# 0            Kerin O’Keefe          @kerinokeefe      87
# 1               Roger Voss            @vossroger      87
# 2             Paul Gregutt           @paulgwine       87
# 3       Alexander Peartree                   NaN      87
# 4             Paul Gregutt           @paulgwine       87
# 5        Michael Schachner           @wineschach      87
# 6            Kerin O’Keefe          @kerinokeefe      87
# 7               Roger Voss            @vossroger      87
# 8       Anna Lee C. Iijima                   NaN      87
# 9               Roger Voss            @vossroger      87
# 10          Virginie Boone               @vboone      87
# 11              Roger Voss            @vossroger      87
# 12          Virginie Boone               @vboone      87
# 13           Kerin O’Keefe          @kerinokeefe      87
# 14           Matt Kettmann         @mattkettmann      87
# ...

# %%
reviews.head(3)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    points  price           province           region_1           region_2  \
# 0      87    NaN  Sicily & Sardinia               Etna                NaN
# 1      87   15.0              Douro                NaN                NaN
# 2      87   14.0             Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# ...

# %%
reviews.set_index('title')
# Out:
#                                                         country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                         Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)          Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)                US
# St. Julian 2013 Reserve Late Harvest Riesling (...           US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...           US
# Tandem 2011 Ars In Vitro Tempranillo-Merlot (Na...        Spain
# Terre di Giurfo 2013 Belsito Frappato (Vittoria)          Italy
# Trimbach 2012 Gewurztraminer (Alsace)                    France
# Heinz Eifel 2013 Shine Gewürztraminer (Rheinhes...      Germany
# Jean-Baptiste Adam 2012 Les Natures Pinot Gris ...       France
# Kirkland Signature 2011 Mountain Cuvée Cabernet...           US
# Leon Beyer 2012 Gewurztraminer (Alsace)                  France
# Louis M. Martini 2012 Cabernet Sauvignon (Alexa...           US
# ...

# %%
reviews.country == 'Italy'
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6          True
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13         True
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22         True
# 23        False
# 24         True
# 25        False
# 26         True
# 27         True
# 28         True
# 29        False
#           ...
# 129941    False
# 129942    False
# 129943     True
# 129944    False
# 129945    False
# 129946    False
# 129947     True
# 129948    False
# 129949    False
# 129950    False
# 129951    False
# 129952    False
# 129953    False
# 129954    False
# 129955    False
# 129956    False
# 129957    False
# 129958    False
# 129959    False
# 129960    False
# 129961     True
# 129962     True
# 129963    False
# 129964    False
# ...

# %%
reviews.loc[(reviews.country=='Italy') | (reviews.points >= 90)]
# Out:
#             country                                        description  \
# 0             Italy  Aromas include tropical fruit, broom, brimston...
# 6             Italy  Here's a bright, informal red that opens with ...
# 13            Italy  This is dominated by oak and oak-driven aromas...
# 22            Italy  Delicate aromas recall white flower and citrus...
# 24            Italy  Aromas of prune, blackcurrant, toast and oak c...
# 26            Italy  Pretty aromas of yellow flower and stone fruit...
# 27            Italy  Aromas recall ripe dark berry, toast and a whi...
# 28            Italy  Aromas suggest mature berry, scorched earth, a...
# 31            Italy  Merlot and Nero d'Avola form the base for this...
# 32            Italy  Part of the extended Calanìca series, this Gri...
# 37            Italy  This concentrated Cabernet offers aromas of cu...
# 38            Italy  Inky in color, this wine has plump aromas of r...
# ...

# %%
reviews.loc[reviews.price.notnull()]
# Out:
#             country                                        description  \
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 2                US  Tart and snappy, the flavors of lime flesh and...
# 3                US  Pineapple rind, lemon pith and orange blossom ...
# 4                US  Much like the regular bottling from 2012, this...
# 5             Spain  Blackberry and raspberry aromas show a typical...
# 6             Italy  Here's a bright, informal red that opens with ...
# 7            France  This dry and restrained wine offers spice in p...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 9            France  This has great depth of flavor with its fresh ...
# 10               US  Soft, supple plum envelopes an oaky structure ...
# 11           France  This is a dry wine, very spicy, with a tight, ...
# 12               US  Slightly reduced, this wine offers a chalky, t...
# ...

# %%
reviews.shape[0]
# Out:
# 129971

# %%
reviews.loc[reviews.country.isin(['Italy', 'France'])]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 7       France  This dry and restrained wine offers spice in p...
# 9       France  This has great depth of flavor with its fresh ...
# 11      France  This is a dry wine, very spicy, with a tight, ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# 26       Italy  Pretty aromas of yellow flower and stone fruit...
# 27       Italy  Aromas recall ripe dark berry, toast and a whi...
# 28       Italy  Aromas suggest mature berry, scorched earth, a...
# 30      France  Red cherry fruit comes laced with light tannin...
# 31       Italy  Merlot and Nero d'Avola form the base for this...
# ...

# %%
reviews['critic']='everyone'

# %%
reviews.head(3)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    points  price           province           region_1           region_2  \
# 0      87    NaN  Sicily & Sardinia               Etna                NaN
# 1      87   15.0              Douro                NaN                NaN
# 2      87   14.0             Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# ...

# %%
reviews['index_backwards'] = range(len(reviews), 0, -1)

# %%
reviews.index_backwards
# Out:
# 0         129971
# 1         129970
# 2         129969
# 3         129968
# 4         129967
# 5         129966
# 6         129965
# 7         129964
# 8         129963
# 9         129962
# 10        129961
# 11        129960
# 12        129959
# 13        129958
# 14        129957
# 15        129956
# 16        129955
# 17        129954
# 18        129953
# 19        129952
# 20        129951
# 21        129950
# 22        129949
# 23        129948
# 24        129947
# 25        129946
# 26        129945
# 27        129944
# 28        129943
# 29        129942
#            ...
# 129941        30
# 129942        29
# 129943        28
# 129944        27
# 129945        26
# 129946        25
# 129947        24
# 129948        23
# 129949        22
# 129950        21
# 129951        20
# 129952        19
# 129953        18
# 129954        17
# 129955        16
# 129956        15
# 129957        14
# 129958        13
# 129959        12
# 129960        11
# 129961        10
# ...

# %%
reviews.description[0]
# Out:
# "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity."

# %%
reviews.iloc[0]
# Out:
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                                        White Blend
# ...

# %%
reviews.loc[0,:]
# Out:
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                                        White Blend
# ...

# %%
reviews.head(3)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    points  price           province           region_1           region_2  \
# 0      87    NaN  Sicily & Sardinia               Etna                NaN
# 1      87   15.0              Douro                NaN                NaN
# 2      87   14.0             Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# ...

# %%
reviews.points.describe()
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %%
reviews.points.mean()
# Out:
# 88.44713820775404

# %%
reviews.taster_name.unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
reviews.taster_name.value_counts()
# Out:
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %%
reviews.head(3)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    points  price           province           region_1           region_2  \
# 0      87    NaN  Sicily & Sardinia               Etna                NaN
# 1      87   15.0              Douro                NaN                NaN
# 2      87   14.0             Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# ...

# %%
review_points_mean = reviews.points.mean()

# %%
pd.set_option('max_rows', 5)
reviews.points.map(lambda p: p - review_points_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
reviews.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery    critic  index_backwards
# 0     White Blend              Nicosia  everyone           129971
# 1  Portuguese Red  Quinta dos Avidagos  everyone           129970

# %%
def remean_points(srs):
    srs.points = srs.points - review_points_mean
    return srs
reviews.apply(remean_points, axis='columns')
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation    points  price           province  \
# 0                        Vulkà Bianco -1.447138    NaN  Sicily & Sardinia
# 1                            Avidagos -1.447138   15.0              Douro
# ...                               ...       ...    ...                ...
# 129969                            NaN  1.552862   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline  1.552862   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
review_price_mean = reviews.loc[reviews.price.notnull()].price.mean()

# %%
review_price_mean
# Out:
# 35.363389129985535

# %%
reviews.loc[reviews.price.isnull()].price.map(lambda p: review_price_mean)
# Out:
# 0         35.363389
# 13        35.363389
#             ...
# 129893    35.363389
# 129964    35.363389
# Name: price, Length: 8996, dtype: float64

# %%
reviews.loc[reviews.price.notnull()].price - review_price_mean
# Out:
# 1        -20.363389
# 2        -21.363389
#             ...
# 129969    -3.363389
# 129970   -14.363389
# Name: price, Length: 120975, dtype: float64
